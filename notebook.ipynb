# %% [markdown]
# <a href="https://colab.research.google.com/github/netcook-app/notebook/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Simple usage and powerful. Good luck ✨**

# %%
# Install library

# !pip install netcook_v2 > /dev/null 2>&1

# %%
from netcook_v2 import checked_cookies

checked_cookies()
# Out:
# ███╗   ██╗███████╗████████╗ ██████╗ ██████╗  ██████╗ ██╗  ██╗
# ████╗  ██║██╔════╝╚══██╔══╝██╔════╝██╔═══██╗██╔═══██╗██║ ██╔╝  script by @NetCook
# ██╔██╗ ██║█████╗     ██║   ██║     ██║   ██║██║   ██║█████╔╝   update version 2.1
# ██║╚██╗██║██╔══╝     ██║   ██║     ██║   ██║██║   ██║██╔═██╗   release 13-10-2024
# ██║ ╚████║███████╗   ██║   ╚██████╗╚██████╔╝╚██████╔╝██║  ██╗  github netcook-app
# ╚═╝  ╚═══╝╚══════╝   ╚═╝    ╚═════╝ ╚═════╝  ╚═════╝ ╚═╝  ╚═╝
# Access NetCook WebUI Site URL: https://app2.dn-project.biz.id
#
# Menu:
# [1] Check Netflix Cookies
# [2] Exit
#
# Enter your choice (1/2): 1
# Please upload a batch file (.zip) or a single file (.json or .txt):
#      <input type="file" id="files-49ce7c81-f77d-44a8-bb9b-dc5af85f634a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49ce7c81-f77d-44a8-bb9b-dc5af85f634a">
#       Upload widget is only available when the cell has been executed in the
# ...
